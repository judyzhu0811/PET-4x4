# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#z = 8.5-9mm
df = pd.read_csv("/Users/judyz/Desktop/PET-4x4/build/3.05mm/3.05mm.csv")
x_min, x_max = -35, 35 
y_min, y_max = -35, 35  
n_bins = 39
x_bins = np.linspace(x_min, x_max, n_bins + 1)
y_bins = np.linspace(y_min, y_max, n_bins + 1)
H, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins], 
    weights=df["LCE (%)"]
)
counts, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins]
)
avg_LCE = np.full_like(H, np.nan, dtype=float)
valid = counts > 0
avg_LCE[valid] = H[valid] / counts[valid]
min_counts = 1   
avg_LCE[counts < min_counts] = np.nan
vmin = np.nanpercentile(avg_LCE, 5)   
vmax = np.nanpercentile(avg_LCE, 95)  
plt.figure(figsize=(8, 7))
mesh = plt.pcolormesh(
    x_bins, y_bins, avg_LCE.T,
    shading='auto',
    cmap='viridis',
    vmin=vmin,
    vmax=vmax
)
plt.colorbar(mesh, label="LCE (%)")
plt.xlabel("X (mm)")
plt.ylabel("Y (mm)")
plt.title(f"LCE Map (bins={n_bins})")
plt.tight_layout()
output_path = "/Users/judyz/Desktop/PET-4x4/build/3.05mm/lce.png"
plt.savefig(output_path, dpi=300)
plt.show()

print("Min LCE:", np.nanmin(avg_LCE))
print("Max LCE:", np.nanmax(avg_LCE))
print("Mean LCE:", np.nanmean(avg_LCE))
# Out:
# Min LCE: 46.80596666666667
# Max LCE: 48.054669230769235
# Mean LCE: 47.71488691297258

# %%
#z = 8.5-9mm
df = pd.read_csv("/Users/judyz/Desktop/PET-4x4/build/4.05mm/4.05mm.csv")
x_min, x_max = -35, 35 
y_min, y_max = -35, 35  
n_bins = 39
x_bins = np.linspace(x_min, x_max, n_bins + 1)
y_bins = np.linspace(y_min, y_max, n_bins + 1)
H, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins], 
    weights=df["LCE (%)"]
)
counts, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins]
)
avg_LCE = np.full_like(H, np.nan, dtype=float)
valid = counts > 0
avg_LCE[valid] = H[valid] / counts[valid]
min_counts = 1   
avg_LCE[counts < min_counts] = np.nan
vmin = np.nanpercentile(avg_LCE, 5)   
vmax = np.nanpercentile(avg_LCE, 95)  
plt.figure(figsize=(8, 7))
mesh = plt.pcolormesh(
    x_bins, y_bins, avg_LCE.T,
    shading='auto',
    cmap='viridis',
    vmin=vmin,
    vmax=vmax
)
plt.colorbar(mesh, label="LCE (%)")
plt.xlabel("X (mm)")
plt.ylabel("Y (mm)")
plt.title(f"LCE Map (bins={n_bins})")
plt.tight_layout()
output_path = "/Users/judyz/Desktop/PET-4x4/build/4.05mm/lce.png"
plt.savefig(output_path, dpi=300)
plt.show()

print("Min LCE:", np.nanmin(avg_LCE))
print("Max LCE:", np.nanmax(avg_LCE))
print("Mean LCE:", np.nanmean(avg_LCE))
# Out:
# Min LCE: 47.03635
# Max LCE: 48.208615384615385
# Mean LCE: 47.89767353833956

# %%
#z = 8.5-9mm
df = pd.read_csv("/Users/judyz/Desktop/PET-4x4/build/5.05mm/5.05mm.csv")
x_min, x_max = -35, 35 
y_min, y_max = -35, 35  
n_bins = 39
x_bins = np.linspace(x_min, x_max, n_bins + 1)
y_bins = np.linspace(y_min, y_max, n_bins + 1)
H, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins], 
    weights=df["LCE (%)"]
)
counts, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins]
)
avg_LCE = np.full_like(H, np.nan, dtype=float)
valid = counts > 0
avg_LCE[valid] = H[valid] / counts[valid]
min_counts = 1   
avg_LCE[counts < min_counts] = np.nan
vmin = np.nanpercentile(avg_LCE, 5)   
vmax = np.nanpercentile(avg_LCE, 95)  
plt.figure(figsize=(8, 7))
mesh = plt.pcolormesh(
    x_bins, y_bins, avg_LCE.T,
    shading='auto',
    cmap='viridis',
    vmin=vmin,
    vmax=vmax
)
plt.colorbar(mesh, label="LCE (%)")
plt.xlabel("X (mm)")
plt.ylabel("Y (mm)")
plt.title(f"LCE Map (bins={n_bins})")
plt.tight_layout()
output_path = "/Users/judyz/Desktop/PET-4x4/build/5.05mm/lce.png"
plt.savefig(output_path, dpi=300)
plt.show()

print("Min LCE:", np.nanmin(avg_LCE))
print("Max LCE:", np.nanmax(avg_LCE))
print("Mean LCE:", np.nanmean(avg_LCE))
# Out:
# Min LCE: 47.15132631578948
# Max LCE: 48.245912162162156
# Mean LCE: 48.00142344197203

# %%
#z = 8.5-9mm
df = pd.read_csv("/Users/judyz/Desktop/PET-4x4/build/6.05mm/6.05mm.csv")
x_min, x_max = -35, 35 
y_min, y_max = -35, 35  
n_bins = 38
x_bins = np.linspace(x_min, x_max, n_bins + 1)
y_bins = np.linspace(y_min, y_max, n_bins + 1)
H, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins], 
    weights=df["LCE (%)"]
)
counts, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins]
)
avg_LCE = np.full_like(H, np.nan, dtype=float)
valid = counts > 0
avg_LCE[valid] = H[valid] / counts[valid]
min_counts = 1   
avg_LCE[counts < min_counts] = np.nan
vmin = np.nanpercentile(avg_LCE, 5)   
vmax = np.nanpercentile(avg_LCE, 95)  
plt.figure(figsize=(8, 7))
mesh = plt.pcolormesh(
    x_bins, y_bins, avg_LCE.T,
    shading='auto',
    cmap='viridis',
    vmin=vmin,
    vmax=vmax
)
plt.colorbar(mesh, label="LCE (%)")
plt.xlabel("X (mm)")
plt.ylabel("Y (mm)")
plt.title(f"LCE Map (bins={n_bins})")
plt.tight_layout()
output_path = "/Users/judyz/Desktop/PET-4x4/build/6.05mm/lce.png"
plt.savefig(output_path, dpi=300)
plt.show()

print("Min LCE:", np.nanmin(avg_LCE))
print("Max LCE:", np.nanmax(avg_LCE))
print("Mean LCE:", np.nanmean(avg_LCE))
# Out:
# Min LCE: 47.243533333333325
# Max LCE: 48.314543750000006
# Mean LCE: 48.049300510230516

# %%
#z = 8.5-9mm
df = pd.read_csv("/Users/judyz/Desktop/PET-4x4/build/7.05mm/7.05mm.csv")
x_min, x_max = -35, 35 
y_min, y_max = -35, 35  
n_bins = 39
x_bins = np.linspace(x_min, x_max, n_bins + 1)
y_bins = np.linspace(y_min, y_max, n_bins + 1)
H, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins], 
    weights=df["LCE (%)"]
)
counts, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins]
)
avg_LCE = np.full_like(H, np.nan, dtype=float)
valid = counts > 0
avg_LCE[valid] = H[valid] / counts[valid]
min_counts = 1   
avg_LCE[counts < min_counts] = np.nan
vmin = np.nanpercentile(avg_LCE, 5)   
vmax = np.nanpercentile(avg_LCE, 95)  
plt.figure(figsize=(8, 7))
mesh = plt.pcolormesh(
    x_bins, y_bins, avg_LCE.T,
    shading='auto',
    cmap='viridis',
    vmin=vmin,
    vmax=vmax
)
plt.colorbar(mesh, label="LCE (%)")
plt.xlabel("X (mm)")
plt.ylabel("Y (mm)")
plt.title(f"LCE Map (bins={n_bins})")
plt.tight_layout()
output_path = "/Users/judyz/Desktop/PET-4x4/build/7.05mm/lce.png"
plt.savefig(output_path, dpi=300)
plt.show()

print("Min LCE:", np.nanmin(avg_LCE))
print("Max LCE:", np.nanmax(avg_LCE))
print("Mean LCE:", np.nanmean(avg_LCE))
# Out:
# Min LCE: 47.108866666666664
# Max LCE: 48.38504285714286
# Mean LCE: 48.07043789729059

# %%
#z = 8.5-9mm
df = pd.read_csv("/Users/judyz/Desktop/PET-4x4/build/8.05mm/8.05mm.csv")
x_min, x_max = -35, 35 
y_min, y_max = -35, 35  
n_bins = 39
x_bins = np.linspace(x_min, x_max, n_bins + 1)
y_bins = np.linspace(y_min, y_max, n_bins + 1)
H, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins], 
    weights=df["LCE (%)"]
)
counts, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins]
)
avg_LCE = np.full_like(H, np.nan, dtype=float)
valid = counts > 0
avg_LCE[valid] = H[valid] / counts[valid]
min_counts = 1   
avg_LCE[counts < min_counts] = np.nan
vmin = np.nanpercentile(avg_LCE, 5)   
vmax = np.nanpercentile(avg_LCE, 95)  
plt.figure(figsize=(8, 7))
mesh = plt.pcolormesh(
    x_bins, y_bins, avg_LCE.T,
    shading='auto',
    cmap='viridis',
    vmin=vmin,
    vmax=vmax
)
plt.colorbar(mesh, label="LCE (%)")
plt.xlabel("X (mm)")
plt.ylabel("Y (mm)")
plt.title(f"LCE Map (bins={n_bins})")
plt.tight_layout()
output_path = "/Users/judyz/Desktop/PET-4x4/build/8.05mm/lce.png"
plt.savefig(output_path, dpi=300)
plt.show()

print("Min LCE:", np.nanmin(avg_LCE))
print("Max LCE:", np.nanmax(avg_LCE))
print("Mean LCE:", np.nanmean(avg_LCE))
# Out:
# Min LCE: 47.187650000000005
# Max LCE: 48.384589999999996
# Mean LCE: 48.07142864939358

# %%
#z = 8.5-9mm
df = pd.read_csv("/Users/judyz/Desktop/PET-4x4/build/9.05mm/9.05mm.csv")
x_min, x_max = -35, 35 
y_min, y_max = -35, 35  
n_bins = 39
x_bins = np.linspace(x_min, x_max, n_bins + 1)
y_bins = np.linspace(y_min, y_max, n_bins + 1)
H, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins], 
    weights=df["LCE (%)"]
)
counts, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins]
)
avg_LCE = np.full_like(H, np.nan, dtype=float)
valid = counts > 0
avg_LCE[valid] = H[valid] / counts[valid]
min_counts = 1   
avg_LCE[counts < min_counts] = np.nan
vmin = np.nanpercentile(avg_LCE, 5)   
vmax = np.nanpercentile(avg_LCE, 95)  
plt.figure(figsize=(8, 7))
mesh = plt.pcolormesh(
    x_bins, y_bins, avg_LCE.T,
    shading='auto',
    cmap='viridis',
    vmin=vmin,
    vmax=vmax
)
plt.colorbar(mesh, label="LCE (%)")
plt.xlabel("X (mm)")
plt.ylabel("Y (mm)")
plt.title(f"LCE Map (bins={n_bins})")
plt.tight_layout()
output_path = "/Users/judyz/Desktop/PET-4x4/build/9.05mm/lce.png"
plt.savefig(output_path, dpi=300)
plt.show()

print("Min LCE:", np.nanmin(avg_LCE))
print("Max LCE:", np.nanmax(avg_LCE))
print("Mean LCE:", np.nanmean(avg_LCE))
# Out:
# Min LCE: 47.276333333333326
# Max LCE: 48.352236363636365
# Mean LCE: 48.05960913284784

# %%
#z = 8.5-9mm
df = pd.read_csv("/Users/judyz/Desktop/PET-4x4/build/10.05mm/10.05mm.csv")
x_min, x_max = -35, 35 
y_min, y_max = -35, 35  
n_bins = 39
x_bins = np.linspace(x_min, x_max, n_bins + 1)
y_bins = np.linspace(y_min, y_max, n_bins + 1)
H, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins], 
    weights=df["LCE (%)"]
)
counts, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins]
)
avg_LCE = np.full_like(H, np.nan, dtype=float)
valid = counts > 0
avg_LCE[valid] = H[valid] / counts[valid]
min_counts = 1   
avg_LCE[counts < min_counts] = np.nan
vmin = np.nanpercentile(avg_LCE, 5)   
vmax = np.nanpercentile(avg_LCE, 95)  
plt.figure(figsize=(8, 7))
mesh = plt.pcolormesh(
    x_bins, y_bins, avg_LCE.T,
    shading='auto',
    cmap='viridis',
    vmin=vmin,
    vmax=vmax
)
plt.colorbar(mesh, label="LCE (%)")
plt.xlabel("X (mm)")
plt.ylabel("Y (mm)")
plt.title(f"LCE Map (bins={n_bins})")
plt.tight_layout()
output_path = "/Users/judyz/Desktop/PET-4x4/build/10.05mm/lce.png"
plt.savefig(output_path, dpi=300)
plt.show()

print("Min LCE:", np.nanmin(avg_LCE))
print("Max LCE:", np.nanmax(avg_LCE))
print("Mean LCE:", np.nanmean(avg_LCE))
# Out:
# Min LCE: 47.249825
# Max LCE: 48.29506
# Mean LCE: 48.032662672506085

# %%
#z = 8.5-9mm
df = pd.read_csv("/Users/judyz/Desktop/PET-4x4/build/11.05mm/11.05mm.csv")
x_min, x_max = -35, 35 
y_min, y_max = -35, 35  
n_bins = 38
x_bins = np.linspace(x_min, x_max, n_bins + 1)
y_bins = np.linspace(y_min, y_max, n_bins + 1)
H, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins], 
    weights=df["LCE (%)"]
)
counts, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins]
)
avg_LCE = np.full_like(H, np.nan, dtype=float)
valid = counts > 0
avg_LCE[valid] = H[valid] / counts[valid]
min_counts = 1   
avg_LCE[counts < min_counts] = np.nan
vmin = np.nanpercentile(avg_LCE, 5)   
vmax = np.nanpercentile(avg_LCE, 95)  
plt.figure(figsize=(8, 7))
mesh = plt.pcolormesh(
    x_bins, y_bins, avg_LCE.T,
    shading='auto',
    cmap='viridis',
    vmin=vmin,
    vmax=vmax
)
plt.colorbar(mesh, label="LCE (%)")
plt.xlabel("X (mm)")
plt.ylabel("Y (mm)")
plt.title(f"LCE Map (bins={n_bins})")
plt.tight_layout()
output_path = "/Users/judyz/Desktop/PET-4x4/build/11.05mm/lce.png"
plt.savefig(output_path, dpi=300)
plt.show()

print("Min LCE:", np.nanmin(avg_LCE))
print("Max LCE:", np.nanmax(avg_LCE))
print("Mean LCE:", np.nanmean(avg_LCE))
# Out:
# Min LCE: 47.15560000000001
# Max LCE: 48.2624
# Mean LCE: 48.00034158511945

# %%
#z = 8.5-9mm
df = pd.read_csv("/Users/judyz/Desktop/PET-4x4/build/12.05mm/12.05mm.csv")
x_min, x_max = -35, 35 
y_min, y_max = -35, 35  
n_bins = 39
x_bins = np.linspace(x_min, x_max, n_bins + 1)
y_bins = np.linspace(y_min, y_max, n_bins + 1)
H, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins], 
    weights=df["LCE (%)"]
)
counts, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins]
)
avg_LCE = np.full_like(H, np.nan, dtype=float)
valid = counts > 0
avg_LCE[valid] = H[valid] / counts[valid]
min_counts = 1   
avg_LCE[counts < min_counts] = np.nan
vmin = np.nanpercentile(avg_LCE, 5)   
vmax = np.nanpercentile(avg_LCE, 95)  
plt.figure(figsize=(8, 7))
mesh = plt.pcolormesh(
    x_bins, y_bins, avg_LCE.T,
    shading='auto',
    cmap='viridis',
    vmin=vmin,
    vmax=vmax
)
plt.colorbar(mesh, label="LCE (%)")
plt.xlabel("X (mm)")
plt.ylabel("Y (mm)")
plt.title(f"LCE Map (bins={n_bins})")
plt.tight_layout()
output_path = "/Users/judyz/Desktop/PET-4x4/build/12.05mm/lce.png"
plt.savefig(output_path, dpi=300)
plt.show()

print("Min LCE:", np.nanmin(avg_LCE))
print("Max LCE:", np.nanmax(avg_LCE))
print("Mean LCE:", np.nanmean(avg_LCE))
# Out:
# Min LCE: 47.11735
# Max LCE: 48.253730000000004
# Mean LCE: 47.96722550746125

# %%
#z = 8.5-9mm
df = pd.read_csv("/Users/judyz/Desktop/PET-4x4/build/13.05mm/13.05mm.csv")
x_min, x_max = -35, 35 
y_min, y_max = -35, 35  
n_bins = 39
x_bins = np.linspace(x_min, x_max, n_bins + 1)
y_bins = np.linspace(y_min, y_max, n_bins + 1)
H, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins], 
    weights=df["LCE (%)"]
)
counts, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins]
)
avg_LCE = np.full_like(H, np.nan, dtype=float)
valid = counts > 0
avg_LCE[valid] = H[valid] / counts[valid]
min_counts = 1   
avg_LCE[counts < min_counts] = np.nan
vmin = np.nanpercentile(avg_LCE, 5)   
vmax = np.nanpercentile(avg_LCE, 95)  
plt.figure(figsize=(8, 7))
mesh = plt.pcolormesh(
    x_bins, y_bins, avg_LCE.T,
    shading='auto',
    cmap='viridis',
    vmin=vmin,
    vmax=vmax
)
plt.colorbar(mesh, label="LCE (%)")
plt.xlabel("X (mm)")
plt.ylabel("Y (mm)")
plt.title(f"LCE Map (bins={n_bins})")
plt.tight_layout()
output_path = "/Users/judyz/Desktop/PET-4x4/build/13.05mm/lce.png"
plt.savefig(output_path, dpi=300)
plt.show()

print("Min LCE:", np.nanmin(avg_LCE))
print("Max LCE:", np.nanmax(avg_LCE))
print("Mean LCE:", np.nanmean(avg_LCE))
# Out:
# Min LCE: 47.14576666666667
# Max LCE: 48.18436666666666
# Mean LCE: 47.93007111155352

# %%
#z = 8.5-9mm
df = pd.read_csv("/Users/judyz/Desktop/PET-4x4/build/14.05mm/14.05mm.csv")
x_min, x_max = -35, 35 
y_min, y_max = -35, 35  
n_bins = 39
x_bins = np.linspace(x_min, x_max, n_bins + 1)
y_bins = np.linspace(y_min, y_max, n_bins + 1)
H, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins], 
    weights=df["LCE (%)"]
)
counts, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins]
)
avg_LCE = np.full_like(H, np.nan, dtype=float)
valid = counts > 0
avg_LCE[valid] = H[valid] / counts[valid]
min_counts = 1   
avg_LCE[counts < min_counts] = np.nan
vmin = np.nanpercentile(avg_LCE, 5)   
vmax = np.nanpercentile(avg_LCE, 95)  
plt.figure(figsize=(8, 7))
mesh = plt.pcolormesh(
    x_bins, y_bins, avg_LCE.T,
    shading='auto',
    cmap='viridis',
    vmin=vmin,
    vmax=vmax
)
plt.colorbar(mesh, label="LCE (%)")
plt.xlabel("X (mm)")
plt.ylabel("Y (mm)")
plt.title(f"LCE Map (bins={n_bins})")
plt.tight_layout()
output_path = "/Users/judyz/Desktop/PET-4x4/build/14.05mm/lce.png"
plt.savefig(output_path, dpi=300)
plt.show()

print("Min LCE:", np.nanmin(avg_LCE))
print("Max LCE:", np.nanmax(avg_LCE))
print("Mean LCE:", np.nanmean(avg_LCE))
# Out:
# Min LCE: 47.144025
# Max LCE: 48.15450833333333
# Mean LCE: 47.895130070257906

# %%
#z = 8.5-9mm
df = pd.read_csv("/Users/judyz/Desktop/PET-4x4/build/14.3mm/14.3mm.csv")
x_min, x_max = -35, 35 
y_min, y_max = -35, 35  
n_bins = 39
x_bins = np.linspace(x_min, x_max, n_bins + 1)
y_bins = np.linspace(y_min, y_max, n_bins + 1)
H, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins], 
    weights=df["LCE (%)"]
)
counts, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins]
)
avg_LCE = np.full_like(H, np.nan, dtype=float)
valid = counts > 0
avg_LCE[valid] = H[valid] / counts[valid]
min_counts = 1   
avg_LCE[counts < min_counts] = np.nan
vmin = np.nanpercentile(avg_LCE, 5)   
vmax = np.nanpercentile(avg_LCE, 95)  
plt.figure(figsize=(8, 7))
mesh = plt.pcolormesh(
    x_bins, y_bins, avg_LCE.T,
    shading='auto',
    cmap='viridis',
    vmin=vmin,
    vmax=vmax
)
plt.colorbar(mesh, label="LCE (%)")
plt.xlabel("X (mm)")
plt.ylabel("Y (mm)")
plt.title(f"LCE Map (bins={n_bins})")
plt.tight_layout()
output_path = "/Users/judyz/Desktop/PET-4x4/build/14.3mm/lce.png"
plt.savefig(output_path, dpi=300)
plt.show()

print("Min LCE:", np.nanmin(avg_LCE))
print("Max LCE:", np.nanmax(avg_LCE))
print("Mean LCE:", np.nanmean(avg_LCE))
# Out:
# Min LCE: 47.24865
# Max LCE: 48.22792
# Mean LCE: 47.8836714369746

# %%
#z = 8.5-9mm
df = pd.read_csv("/Users/judyz/Desktop/PET-4x4/build/14.55mm/14.55mm.csv")
x_min, x_max = -35, 35 
y_min, y_max = -35, 35  
n_bins = 39
x_bins = np.linspace(x_min, x_max, n_bins + 1)
y_bins = np.linspace(y_min, y_max, n_bins + 1)
H, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins], 
    weights=df["LCE (%)"]
)
counts, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins]
)
avg_LCE = np.full_like(H, np.nan, dtype=float)
valid = counts > 0
avg_LCE[valid] = H[valid] / counts[valid]
min_counts = 1   
avg_LCE[counts < min_counts] = np.nan
vmin = np.nanpercentile(avg_LCE, 5)   
vmax = np.nanpercentile(avg_LCE, 95)  
plt.figure(figsize=(8, 7))
mesh = plt.pcolormesh(
    x_bins, y_bins, avg_LCE.T,
    shading='auto',
    cmap='viridis',
    vmin=vmin,
    vmax=vmax
)
plt.colorbar(mesh, label="LCE (%)")
plt.xlabel("X (mm)")
plt.ylabel("Y (mm)")
plt.title(f"LCE Map (bins={n_bins})")
plt.tight_layout()
output_path = "/Users/judyz/Desktop/PET-4x4/build/14.55mm/lce.png"
plt.savefig(output_path, dpi=300)
plt.show()

print("Min LCE:", np.nanmin(avg_LCE))
print("Max LCE:", np.nanmax(avg_LCE))
print("Mean LCE:", np.nanmean(avg_LCE))
# Out:
# Min LCE: 47.27835
# Max LCE: 48.14992222222223
# Mean LCE: 47.87230001709109

# %%
#z = 8.5-9mm
df = pd.read_csv("/Users/judyz/Desktop/PET-4x4/build/14.8mm/14.8mm.csv")
x_min, x_max = -35, 35 
y_min, y_max = -35, 35  
n_bins = 39
x_bins = np.linspace(x_min, x_max, n_bins + 1)
y_bins = np.linspace(y_min, y_max, n_bins + 1)
H, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins], 
    weights=df["LCE (%)"]
)
counts, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins]
)
avg_LCE = np.full_like(H, np.nan, dtype=float)
valid = counts > 0
avg_LCE[valid] = H[valid] / counts[valid]
min_counts = 1   
avg_LCE[counts < min_counts] = np.nan
vmin = np.nanpercentile(avg_LCE, 5)   
vmax = np.nanpercentile(avg_LCE, 95)  
plt.figure(figsize=(8, 7))
mesh = plt.pcolormesh(
    x_bins, y_bins, avg_LCE.T,
    shading='auto',
    cmap='viridis',
    vmin=vmin,
    vmax=vmax
)
plt.colorbar(mesh, label="LCE (%)")
plt.xlabel("X (mm)")
plt.ylabel("Y (mm)")
plt.title(f"LCE Map (bins={n_bins})")
plt.tight_layout()
output_path = "/Users/judyz/Desktop/PET-4x4/build/14.8mm/lce.png"
plt.savefig(output_path, dpi=300)
plt.show()

print("Min LCE:", np.nanmin(avg_LCE))
print("Max LCE:", np.nanmax(avg_LCE))
print("Mean LCE:", np.nanmean(avg_LCE))
# Out:
# Min LCE: 47.379149999999996
# Max LCE: 48.60211666666667
# Mean LCE: 48.1378694519267

# %%
#z = 8.5-9mm
df = pd.read_csv("/Users/judyz/Desktop/PET-4x4/build/15.05mm/15.05mm.csv")
x_min, x_max = -35, 35 
y_min, y_max = -35, 35  
n_bins = 38
x_bins = np.linspace(x_min, x_max, n_bins + 1)
y_bins = np.linspace(y_min, y_max, n_bins + 1)
H, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins], 
    weights=df["LCE (%)"]
)
counts, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins]
)
avg_LCE = np.full_like(H, np.nan, dtype=float)
valid = counts > 0
avg_LCE[valid] = H[valid] / counts[valid]
min_counts = 1   
avg_LCE[counts < min_counts] = np.nan
vmin = np.nanpercentile(avg_LCE, 5)   
vmax = np.nanpercentile(avg_LCE, 95)  
plt.figure(figsize=(8, 7))
mesh = plt.pcolormesh(
    x_bins, y_bins, avg_LCE.T,
    shading='auto',
    cmap='viridis',
    vmin=vmin,
    vmax=vmax
)
plt.colorbar(mesh, label="LCE (%)")
plt.xlabel("X (mm)")
plt.ylabel("Y (mm)")
plt.title(f"LCE Map (bins={n_bins})")
plt.tight_layout()
output_path = "/Users/judyz/Desktop/PET-4x4/build/15.05mm/lce.png"
plt.savefig(output_path, dpi=300)
plt.show()

print("Min LCE:", np.nanmin(avg_LCE))
print("Max LCE:", np.nanmax(avg_LCE))
print("Mean LCE:", np.nanmean(avg_LCE))
# Out:
# Min LCE: 47.59317692307692
# Max LCE: 48.70740000000001
# Mean LCE: 48.40117506968668

# %%
#z = 8.5-9mm
df = pd.read_csv("/Users/judyz/Desktop/PET-4x4/build/15.3mm/15.3mm.csv")
x_min, x_max = -35, 35 
y_min, y_max = -35, 35  
n_bins = 39
x_bins = np.linspace(x_min, x_max, n_bins + 1)
y_bins = np.linspace(y_min, y_max, n_bins + 1)
H, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins], 
    weights=df["LCE (%)"]
)
counts, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins]
)
avg_LCE = np.full_like(H, np.nan, dtype=float)
valid = counts > 0
avg_LCE[valid] = H[valid] / counts[valid]
min_counts = 1   
avg_LCE[counts < min_counts] = np.nan
vmin = np.nanpercentile(avg_LCE, 5)   
vmax = np.nanpercentile(avg_LCE, 95)  
plt.figure(figsize=(8, 7))
mesh = plt.pcolormesh(
    x_bins, y_bins, avg_LCE.T,
    shading='auto',
    cmap='viridis',
    vmin=vmin,
    vmax=vmax
)
plt.colorbar(mesh, label="LCE (%)")
plt.xlabel("X (mm)")
plt.ylabel("Y (mm)")
plt.title(f"LCE Map (bins={n_bins})")
plt.tight_layout()
output_path = "/Users/judyz/Desktop/PET-4x4/build/15.3mm/lce.png"
plt.savefig(output_path, dpi=300)
plt.show()

print("Min LCE:", np.nanmin(avg_LCE))
print("Max LCE:", np.nanmax(avg_LCE))
print("Mean LCE:", np.nanmean(avg_LCE))
# Out:
# Min LCE: 47.510175
# Max LCE: 49.78666666666666
# Mean LCE: 48.86487539506627

# %%
#z = 8.5-9mm
df = pd.read_csv("/Users/judyz/Desktop/PET-4x4/build/15.55mm/15.55mm.csv")
x_min, x_max = -35, 35 
y_min, y_max = -35, 35  
n_bins = 37
x_bins = np.linspace(x_min, x_max, n_bins + 1)
y_bins = np.linspace(y_min, y_max, n_bins + 1)
H, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins], 
    weights=df["LCE (%)"]
)
counts, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins]
)
avg_LCE = np.full_like(H, np.nan, dtype=float)
valid = counts > 0
avg_LCE[valid] = H[valid] / counts[valid]
min_counts = 1   
avg_LCE[counts < min_counts] = np.nan
vmin = np.nanpercentile(avg_LCE, 5)   
vmax = np.nanpercentile(avg_LCE, 95)  
plt.figure(figsize=(8, 7))
mesh = plt.pcolormesh(
    x_bins, y_bins, avg_LCE.T,
    shading='auto',
    cmap='viridis',
    vmin=vmin,
    vmax=vmax
)
plt.colorbar(mesh, label="LCE (%)")
plt.xlabel("X (mm)")
plt.ylabel("Y (mm)")
plt.title(f"LCE Map (bins={n_bins})")
plt.tight_layout()
output_path = "/Users/judyz/Desktop/PET-4x4/build/15.55mm/lce.png"
plt.savefig(output_path, dpi=300)
plt.show()

print("Min LCE:", np.nanmin(avg_LCE))
print("Max LCE:", np.nanmax(avg_LCE))
print("Mean LCE:", np.nanmean(avg_LCE))
# Out:
# Min LCE: 47.98417142857142
# Max LCE: 50.161122222222225
# Mean LCE: 49.32255531717611

# %%
#z = 8.5-9mm
df = pd.read_csv("/Users/judyz/Desktop/PET-4x4/build/15.8mm/15.8mm.csv")
x_min, x_max = -35, 35 
y_min, y_max = -35, 35  
n_bins = 37
x_bins = np.linspace(x_min, x_max, n_bins + 1)
y_bins = np.linspace(y_min, y_max, n_bins + 1)
H, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins], 
    weights=df["LCE (%)"]
)
counts, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins]
)
avg_LCE = np.full_like(H, np.nan, dtype=float)
valid = counts > 0
avg_LCE[valid] = H[valid] / counts[valid]
min_counts = 1   
avg_LCE[counts < min_counts] = np.nan
vmin = np.nanpercentile(avg_LCE, 5)   
vmax = np.nanpercentile(avg_LCE, 95)  
plt.figure(figsize=(8, 7))
mesh = plt.pcolormesh(
    x_bins, y_bins, avg_LCE.T,
    shading='auto',
    cmap='viridis',
    vmin=vmin,
    vmax=vmax
)
plt.colorbar(mesh, label="LCE (%)")
plt.xlabel("X (mm)")
plt.ylabel("Y (mm)")
plt.title(f"LCE Map (bins={n_bins})")
plt.tight_layout()
output_path = "/Users/judyz/Desktop/PET-4x4/build/15.8mm/lce.png"
plt.savefig(output_path, dpi=300)
plt.show()

print("Min LCE:", np.nanmin(avg_LCE))
print("Max LCE:", np.nanmax(avg_LCE))
print("Mean LCE:", np.nanmean(avg_LCE))
# Out:
# Min LCE: 47.99086666666667
# Max LCE: 50.16728461538462
# Mean LCE: 49.315857754676564

# %%
#z = 8.5-9mm
df = pd.read_csv("/Users/judyz/Desktop/PET-4x4/build/16.05mm/16.05mm.csv")
x_min, x_max = -35, 35 
y_min, y_max = -35, 35  
n_bins = 38
x_bins = np.linspace(x_min, x_max, n_bins + 1)
y_bins = np.linspace(y_min, y_max, n_bins + 1)
H, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins], 
    weights=df["LCE (%)"]
)
counts, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins]
)
avg_LCE = np.full_like(H, np.nan, dtype=float)
valid = counts > 0
avg_LCE[valid] = H[valid] / counts[valid]
min_counts = 1   
avg_LCE[counts < min_counts] = np.nan
vmin = np.nanpercentile(avg_LCE, 5)   
vmax = np.nanpercentile(avg_LCE, 95)  
plt.figure(figsize=(8, 7))
mesh = plt.pcolormesh(
    x_bins, y_bins, avg_LCE.T,
    shading='auto',
    cmap='viridis',
    vmin=vmin,
    vmax=vmax
)
plt.colorbar(mesh, label="LCE (%)")
plt.xlabel("X (mm)")
plt.ylabel("Y (mm)")
plt.title(f"LCE Map (bins={n_bins})")
plt.tight_layout()
output_path = "/Users/judyz/Desktop/PET-4x4/build/16.05mm/lce.png"
plt.savefig(output_path, dpi=300)
plt.show()

print("Min LCE:", np.nanmin(avg_LCE))
print("Max LCE:", np.nanmax(avg_LCE))
print("Mean LCE:", np.nanmean(avg_LCE))
# Out:
# Min LCE: 47.9743
# Max LCE: 50.163700000000006
# Mean LCE: 49.31001645448727

# %%
#z = 8.5-9mm
df = pd.read_csv("/Users/judyz/Desktop/PET-4x4/build/16.3mm/16.3mm.csv")
x_min, x_max = -35, 35 
y_min, y_max = -35, 35  
n_bins = 38
x_bins = np.linspace(x_min, x_max, n_bins + 1)
y_bins = np.linspace(y_min, y_max, n_bins + 1)
H, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins], 
    weights=df["LCE (%)"]
)
counts, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins]
)
avg_LCE = np.full_like(H, np.nan, dtype=float)
valid = counts > 0
avg_LCE[valid] = H[valid] / counts[valid]
min_counts = 1   
avg_LCE[counts < min_counts] = np.nan
vmin = np.nanpercentile(avg_LCE, 5)   
vmax = np.nanpercentile(avg_LCE, 95)  
plt.figure(figsize=(8, 7))
mesh = plt.pcolormesh(
    x_bins, y_bins, avg_LCE.T,
    shading='auto',
    cmap='viridis',
    vmin=vmin,
    vmax=vmax
)
plt.colorbar(mesh, label="LCE (%)")
plt.xlabel("X (mm)")
plt.ylabel("Y (mm)")
plt.title(f"LCE Map (bins={n_bins})")
plt.tight_layout()
output_path = "/Users/judyz/Desktop/PET-4x4/build/16.3mm/lce.png"
plt.savefig(output_path, dpi=300)
plt.show()

print("Min LCE:", np.nanmin(avg_LCE))
print("Max LCE:", np.nanmax(avg_LCE))
print("Mean LCE:", np.nanmean(avg_LCE))
# Out:
# Min LCE: 47.90835
# Max LCE: 50.15909090909091
# Mean LCE: 49.305742973434576

# %%
#z = 8.5-9mm
df = pd.read_csv("/Users/judyz/Desktop/PET-4x4/build/16.55mm/16.55mm.csv")
x_min, x_max = -35, 35 
y_min, y_max = -35, 35  
n_bins = 38
x_bins = np.linspace(x_min, x_max, n_bins + 1)
y_bins = np.linspace(y_min, y_max, n_bins + 1)
H, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins], 
    weights=df["LCE (%)"]
)
counts, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins]
)
avg_LCE = np.full_like(H, np.nan, dtype=float)
valid = counts > 0
avg_LCE[valid] = H[valid] / counts[valid]
min_counts = 1   
avg_LCE[counts < min_counts] = np.nan
vmin = np.nanpercentile(avg_LCE, 5)   
vmax = np.nanpercentile(avg_LCE, 95)  
plt.figure(figsize=(8, 7))
mesh = plt.pcolormesh(
    x_bins, y_bins, avg_LCE.T,
    shading='auto',
    cmap='viridis',
    vmin=vmin,
    vmax=vmax
)
plt.colorbar(mesh, label="LCE (%)")
plt.xlabel("X (mm)")
plt.ylabel("Y (mm)")
plt.title(f"LCE Map (bins={n_bins})")
plt.tight_layout()
output_path = "/Users/judyz/Desktop/PET-4x4/build/16.55mm/lce.png"
plt.savefig(output_path, dpi=300)
plt.show()

print("Min LCE:", np.nanmin(avg_LCE))
print("Max LCE:", np.nanmax(avg_LCE))
print("Mean LCE:", np.nanmean(avg_LCE))
# Out:
# Min LCE: 47.9553
# Max LCE: 50.149888888888896
# Mean LCE: 49.299988767987784

# %%
#z = 8.5-9mm
df = pd.read_csv("/Users/judyz/Desktop/PET-4x4/build/16.8mm/16.8mm.csv")
x_min, x_max = -35, 35 
y_min, y_max = -35, 35  
n_bins = 38
x_bins = np.linspace(x_min, x_max, n_bins + 1)
y_bins = np.linspace(y_min, y_max, n_bins + 1)
H, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins], 
    weights=df["LCE (%)"]
)
counts, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins]
)
avg_LCE = np.full_like(H, np.nan, dtype=float)
valid = counts > 0
avg_LCE[valid] = H[valid] / counts[valid]
min_counts = 1   
avg_LCE[counts < min_counts] = np.nan
vmin = np.nanpercentile(avg_LCE, 5)   
vmax = np.nanpercentile(avg_LCE, 95)  
plt.figure(figsize=(8, 7))
mesh = plt.pcolormesh(
    x_bins, y_bins, avg_LCE.T,
    shading='auto',
    cmap='viridis',
    vmin=vmin,
    vmax=vmax
)
plt.colorbar(mesh, label="LCE (%)")
plt.xlabel("X (mm)")
plt.ylabel("Y (mm)")
plt.title(f"LCE Map (bins={n_bins})")
plt.tight_layout()
output_path = "/Users/judyz/Desktop/PET-4x4/build/16.8mm/lce.png"
plt.savefig(output_path, dpi=300)
plt.show()

print("Min LCE:", np.nanmin(avg_LCE))
print("Max LCE:", np.nanmax(avg_LCE))
print("Mean LCE:", np.nanmean(avg_LCE))
# Out:
# Min LCE: 47.9773
# Max LCE: 50.132259999999995
# Mean LCE: 49.29601991584389

# %%
#z = 8.5-9mm
df = pd.read_csv("/Users/judyz/Desktop/PET-4x4/build/17.05mm/17.05mm.csv")
x_min, x_max = -35, 35 
y_min, y_max = -35, 35  
n_bins = 36
x_bins = np.linspace(x_min, x_max, n_bins + 1)
y_bins = np.linspace(y_min, y_max, n_bins + 1)
H, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins], 
    weights=df["LCE (%)"]
)
counts, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins]
)
avg_LCE = np.full_like(H, np.nan, dtype=float)
valid = counts > 0
avg_LCE[valid] = H[valid] / counts[valid]
min_counts = 1   
avg_LCE[counts < min_counts] = np.nan
vmin = np.nanpercentile(avg_LCE, 5)   
vmax = np.nanpercentile(avg_LCE, 95)  
plt.figure(figsize=(8, 7))
mesh = plt.pcolormesh(
    x_bins, y_bins, avg_LCE.T,
    shading='auto',
    cmap='viridis',
    vmin=vmin,
    vmax=vmax
)
plt.colorbar(mesh, label="LCE (%)")
plt.xlabel("X (mm)")
plt.ylabel("Y (mm)")
plt.title(f"LCE Map (bins={n_bins})")
plt.tight_layout()
output_path = "/Users/judyz/Desktop/PET-4x4/build/17.05mm/lce.png"
plt.savefig(output_path, dpi=300)
plt.show()

print("Min LCE:", np.nanmin(avg_LCE))
print("Max LCE:", np.nanmax(avg_LCE))
print("Mean LCE:", np.nanmean(avg_LCE))
# Out:
# Min LCE: 47.8807
# Max LCE: 50.103223529411764
# Mean LCE: 49.2943771406398

# %%
#z = 8.5-9mm
df = pd.read_csv("/Users/judyz/Desktop/PET-4x4/build/17.3mm/17.3mm.csv")
x_min, x_max = -35, 35 
y_min, y_max = -35, 35  
n_bins = 38
x_bins = np.linspace(x_min, x_max, n_bins + 1)
y_bins = np.linspace(y_min, y_max, n_bins + 1)
H, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins], 
    weights=df["LCE (%)"]
)
counts, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins]
)
avg_LCE = np.full_like(H, np.nan, dtype=float)
valid = counts > 0
avg_LCE[valid] = H[valid] / counts[valid]
min_counts = 1   
avg_LCE[counts < min_counts] = np.nan
vmin = np.nanpercentile(avg_LCE, 5)   
vmax = np.nanpercentile(avg_LCE, 95)  
plt.figure(figsize=(8, 7))
mesh = plt.pcolormesh(
    x_bins, y_bins, avg_LCE.T,
    shading='auto',
    cmap='viridis',
    vmin=vmin,
    vmax=vmax
)
plt.colorbar(mesh, label="LCE (%)")
plt.xlabel("X (mm)")
plt.ylabel("Y (mm)")
plt.title(f"LCE Map (bins={n_bins})")
plt.tight_layout()
output_path = "/Users/judyz/Desktop/PET-4x4/build/17.3mm/lce.png"
plt.savefig(output_path, dpi=300)
plt.show()

print("Min LCE:", np.nanmin(avg_LCE))
print("Max LCE:", np.nanmax(avg_LCE))
print("Mean LCE:", np.nanmean(avg_LCE))
# Out:
# Min LCE: 47.969366666666666
# Max LCE: 50.09666666666667
# Mean LCE: 49.29096404318979

# %%
#z = 8.5-9mm
df = pd.read_csv("/Users/judyz/Desktop/PET-4x4/build/17.55mm/17.55mm.csv")
x_min, x_max = -35, 35 
y_min, y_max = -35, 35  
n_bins = 38
x_bins = np.linspace(x_min, x_max, n_bins + 1)
y_bins = np.linspace(y_min, y_max, n_bins + 1)
H, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins], 
    weights=df["LCE (%)"]
)
counts, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins]
)
avg_LCE = np.full_like(H, np.nan, dtype=float)
valid = counts > 0
avg_LCE[valid] = H[valid] / counts[valid]
min_counts = 1   
avg_LCE[counts < min_counts] = np.nan
vmin = np.nanpercentile(avg_LCE, 5)   
vmax = np.nanpercentile(avg_LCE, 95)  
plt.figure(figsize=(8, 7))
mesh = plt.pcolormesh(
    x_bins, y_bins, avg_LCE.T,
    shading='auto',
    cmap='viridis',
    vmin=vmin,
    vmax=vmax
)
plt.colorbar(mesh, label="LCE (%)")
plt.xlabel("X (mm)")
plt.ylabel("Y (mm)")
plt.title(f"LCE Map (bins={n_bins})")
plt.tight_layout()
output_path = "/Users/judyz/Desktop/PET-4x4/build/17.55mm/lce.png"
plt.savefig(output_path, dpi=300)
plt.show()

print("Min LCE:", np.nanmin(avg_LCE))
print("Max LCE:", np.nanmax(avg_LCE))
print("Mean LCE:", np.nanmean(avg_LCE))
# Out:
# Min LCE: 47.88484999999999
# Max LCE: 50.0872588235294
# Mean LCE: 49.284004799115664

# %%
#z = 8.5-9mm
df = pd.read_csv("/Users/judyz/Desktop/PET-4x4/build/17.8mm/17.8mm.csv")
x_min, x_max = -35, 35 
y_min, y_max = -35, 35  
n_bins = 38
x_bins = np.linspace(x_min, x_max, n_bins + 1)
y_bins = np.linspace(y_min, y_max, n_bins + 1)
H, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins], 
    weights=df["LCE (%)"]
)
counts, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins]
)
avg_LCE = np.full_like(H, np.nan, dtype=float)
valid = counts > 0
avg_LCE[valid] = H[valid] / counts[valid]
min_counts = 1   
avg_LCE[counts < min_counts] = np.nan
vmin = np.nanpercentile(avg_LCE, 5)   
vmax = np.nanpercentile(avg_LCE, 95)  
plt.figure(figsize=(8, 7))
mesh = plt.pcolormesh(
    x_bins, y_bins, avg_LCE.T,
    shading='auto',
    cmap='viridis',
    vmin=vmin,
    vmax=vmax
)
plt.colorbar(mesh, label="LCE (%)")
plt.xlabel("X (mm)")
plt.ylabel("Y (mm)")
plt.title(f"LCE Map (bins={n_bins})")
plt.tight_layout()
output_path = "/Users/judyz/Desktop/PET-4x4/build/17.8mm/lce.png"
plt.savefig(output_path, dpi=300)
plt.show()

print("Min LCE:", np.nanmin(avg_LCE))
print("Max LCE:", np.nanmax(avg_LCE))
print("Mean LCE:", np.nanmean(avg_LCE))
# Out:
# Min LCE: 47.931
# Max LCE: 50.11611818181818
# Mean LCE: 49.28328683655228

# %%
#z = 8.5-9mm
df = pd.read_csv("/Users/judyz/Desktop/PET-4x4/build/18.05mm/18.05mm.csv")
x_min, x_max = -35, 35 
y_min, y_max = -35, 35  
n_bins = 38
x_bins = np.linspace(x_min, x_max, n_bins + 1)
y_bins = np.linspace(y_min, y_max, n_bins + 1)
H, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins], 
    weights=df["LCE (%)"]
)
counts, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins]
)
avg_LCE = np.full_like(H, np.nan, dtype=float)
valid = counts > 0
avg_LCE[valid] = H[valid] / counts[valid]
min_counts = 1   
avg_LCE[counts < min_counts] = np.nan
vmin = np.nanpercentile(avg_LCE, 5)   
vmax = np.nanpercentile(avg_LCE, 95)  
plt.figure(figsize=(8, 7))
mesh = plt.pcolormesh(
    x_bins, y_bins, avg_LCE.T,
    shading='auto',
    cmap='viridis',
    vmin=vmin,
    vmax=vmax
)
plt.colorbar(mesh, label="LCE (%)")
plt.xlabel("X (mm)")
plt.ylabel("Y (mm)")
plt.title(f"LCE Map (bins={n_bins})")
plt.tight_layout()
output_path = "/Users/judyz/Desktop/PET-4x4/build/18.05mm/lce.png"
plt.savefig(output_path, dpi=300)
plt.show()

print("Min LCE:", np.nanmin(avg_LCE))
print("Max LCE:", np.nanmax(avg_LCE))
print("Mean LCE:", np.nanmean(avg_LCE))
# Out:
# Min LCE: 47.94001428571429
# Max LCE: 50.06075
# Mean LCE: 49.28141675131428

# %%
#z = 8.5-9mm
df = pd.read_csv("/Users/judyz/Desktop/PET-4x4/build/18.3mm/18.3mm.csv")
x_min, x_max = -35, 35 
y_min, y_max = -35, 35  
n_bins = 38
x_bins = np.linspace(x_min, x_max, n_bins + 1)
y_bins = np.linspace(y_min, y_max, n_bins + 1)
H, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins], 
    weights=df["LCE (%)"]
)
counts, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins]
)
avg_LCE = np.full_like(H, np.nan, dtype=float)
valid = counts > 0
avg_LCE[valid] = H[valid] / counts[valid]
min_counts = 1   
avg_LCE[counts < min_counts] = np.nan
vmin = np.nanpercentile(avg_LCE, 5)   
vmax = np.nanpercentile(avg_LCE, 95)  
plt.figure(figsize=(8, 7))
mesh = plt.pcolormesh(
    x_bins, y_bins, avg_LCE.T,
    shading='auto',
    cmap='viridis',
    vmin=vmin,
    vmax=vmax
)
plt.colorbar(mesh, label="LCE (%)")
plt.xlabel("X (mm)")
plt.ylabel("Y (mm)")
plt.title(f"LCE Map (bins={n_bins})")
plt.tight_layout()
output_path = "/Users/judyz/Desktop/PET-4x4/build/18.3mm/lce.png"
plt.savefig(output_path, dpi=300)
plt.show()

print("Min LCE:", np.nanmin(avg_LCE))
print("Max LCE:", np.nanmax(avg_LCE))
print("Mean LCE:", np.nanmean(avg_LCE))
# Out:
# Min LCE: 47.873174999999996
# Max LCE: 50.03175384615385
# Mean LCE: 49.279084043160296

# %%
#z = 8.5-9mm
df = pd.read_csv("/Users/judyz/Desktop/PET-4x4/build/18.55mm/18.55mm.csv")
x_min, x_max = -35, 35 
y_min, y_max = -35, 35  
n_bins = 38
x_bins = np.linspace(x_min, x_max, n_bins + 1)
y_bins = np.linspace(y_min, y_max, n_bins + 1)
H, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins], 
    weights=df["LCE (%)"]
)
counts, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins]
)
avg_LCE = np.full_like(H, np.nan, dtype=float)
valid = counts > 0
avg_LCE[valid] = H[valid] / counts[valid]
min_counts = 1   
avg_LCE[counts < min_counts] = np.nan
vmin = np.nanpercentile(avg_LCE, 5)   
vmax = np.nanpercentile(avg_LCE, 95)  
plt.figure(figsize=(8, 7))
mesh = plt.pcolormesh(
    x_bins, y_bins, avg_LCE.T,
    shading='auto',
    cmap='viridis',
    vmin=vmin,
    vmax=vmax
)
plt.colorbar(mesh, label="LCE (%)")
plt.xlabel("X (mm)")
plt.ylabel("Y (mm)")
plt.title(f"LCE Map (bins={n_bins})")
plt.tight_layout()
output_path = "/Users/judyz/Desktop/PET-4x4/build/18.55mm/lce.png"
plt.savefig(output_path, dpi=300)
plt.show()

print("Min LCE:", np.nanmin(avg_LCE))
print("Max LCE:", np.nanmax(avg_LCE))
print("Mean LCE:", np.nanmean(avg_LCE))
# Out:
# Min LCE: 47.933460000000004
# Max LCE: 50.10834166666667
# Mean LCE: 49.27349494056619

# %%
#z = 8.5-9mm
df = pd.read_csv("/Users/judyz/Desktop/PET-4x4/build/18.8mm/18.8mm.csv")
x_min, x_max = -35, 35 
y_min, y_max = -35, 35  
n_bins = 38
x_bins = np.linspace(x_min, x_max, n_bins + 1)
y_bins = np.linspace(y_min, y_max, n_bins + 1)
H, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins], 
    weights=df["LCE (%)"]
)
counts, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins]
)
avg_LCE = np.full_like(H, np.nan, dtype=float)
valid = counts > 0
avg_LCE[valid] = H[valid] / counts[valid]
min_counts = 1   
avg_LCE[counts < min_counts] = np.nan
vmin = np.nanpercentile(avg_LCE, 5)   
vmax = np.nanpercentile(avg_LCE, 95)  
plt.figure(figsize=(8, 7))
mesh = plt.pcolormesh(
    x_bins, y_bins, avg_LCE.T,
    shading='auto',
    cmap='viridis',
    vmin=vmin,
    vmax=vmax
)
plt.colorbar(mesh, label="LCE (%)")
plt.xlabel("X (mm)")
plt.ylabel("Y (mm)")
plt.title(f"LCE Map (bins={n_bins})")
plt.tight_layout()
output_path = "/Users/judyz/Desktop/PET-4x4/build/18.8mm/lce.png"
plt.savefig(output_path, dpi=300)
plt.show()

print("Min LCE:", np.nanmin(avg_LCE))
print("Max LCE:", np.nanmax(avg_LCE))
print("Mean LCE:", np.nanmean(avg_LCE))
# Out:
# Min LCE: 47.87335
# Max LCE: 50.03347
# Mean LCE: 49.27079872849971

# %%
#z = 8.5-9mm
df = pd.read_csv("/Users/judyz/Desktop/PET-4x4/build/19.05mm/19.05mm.csv")
x_min, x_max = -35, 35 
y_min, y_max = -35, 35  
n_bins = 37
x_bins = np.linspace(x_min, x_max, n_bins + 1)
y_bins = np.linspace(y_min, y_max, n_bins + 1)
H, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins], 
    weights=df["LCE (%)"]
)
counts, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins]
)
avg_LCE = np.full_like(H, np.nan, dtype=float)
valid = counts > 0
avg_LCE[valid] = H[valid] / counts[valid]
min_counts = 1   
avg_LCE[counts < min_counts] = np.nan
vmin = np.nanpercentile(avg_LCE, 5)   
vmax = np.nanpercentile(avg_LCE, 95)  
plt.figure(figsize=(8, 7))
mesh = plt.pcolormesh(
    x_bins, y_bins, avg_LCE.T,
    shading='auto',
    cmap='viridis',
    vmin=vmin,
    vmax=vmax
)
plt.colorbar(mesh, label="LCE (%)")
plt.xlabel("X (mm)")
plt.ylabel("Y (mm)")
plt.title(f"LCE Map (bins={n_bins})")
plt.tight_layout()
output_path = "/Users/judyz/Desktop/PET-4x4/build/19.05mm/lce.png"
plt.savefig(output_path, dpi=300)
plt.show()

print("Min LCE:", np.nanmin(avg_LCE))
print("Max LCE:", np.nanmax(avg_LCE))
print("Mean LCE:", np.nanmean(avg_LCE))
# Out:
# Min LCE: 47.95353333333333
# Max LCE: 50.00546363636363
# Mean LCE: 49.26750808157945

# %%
#z = 8.5-9mm
df = pd.read_csv("/Users/judyz/Desktop/PET-4x4/build/20.05mm/20.05mm.csv")
x_min, x_max = -35, 35 
y_min, y_max = -35, 35  
n_bins = 38
x_bins = np.linspace(x_min, x_max, n_bins + 1)
y_bins = np.linspace(y_min, y_max, n_bins + 1)
H, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins], 
    weights=df["LCE (%)"]
)
counts, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins]
)
avg_LCE = np.full_like(H, np.nan, dtype=float)
valid = counts > 0
avg_LCE[valid] = H[valid] / counts[valid]
min_counts = 1   
avg_LCE[counts < min_counts] = np.nan
vmin = np.nanpercentile(avg_LCE, 5)   
vmax = np.nanpercentile(avg_LCE, 95)  
plt.figure(figsize=(8, 7))
mesh = plt.pcolormesh(
    x_bins, y_bins, avg_LCE.T,
    shading='auto',
    cmap='viridis',
    vmin=vmin,
    vmax=vmax
)
plt.colorbar(mesh, label="LCE (%)")
plt.xlabel("X (mm)")
plt.ylabel("Y (mm)")
plt.title(f"LCE Map (bins={n_bins})")
plt.tight_layout()
output_path = "/Users/judyz/Desktop/PET-4x4/build/20.05mm/lce.png"
plt.savefig(output_path, dpi=300)
plt.show()

print("Min LCE:", np.nanmin(avg_LCE))
print("Max LCE:", np.nanmax(avg_LCE))
print("Mean LCE:", np.nanmean(avg_LCE))
# Out:
# Min LCE: 47.8487
# Max LCE: 49.949942105263155
# Mean LCE: 49.25081342842214

# %%
#z = 8.5-9mm
df = pd.read_csv("/Users/judyz/Desktop/PET-4x4/build/25.05mm/25.05mm.csv")
x_min, x_max = -35, 35 
y_min, y_max = -35, 35  
n_bins = 37
x_bins = np.linspace(x_min, x_max, n_bins + 1)
y_bins = np.linspace(y_min, y_max, n_bins + 1)
H, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins], 
    weights=df["LCE (%)"]
)
counts, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins]
)
avg_LCE = np.full_like(H, np.nan, dtype=float)
valid = counts > 0
avg_LCE[valid] = H[valid] / counts[valid]
min_counts = 1   
avg_LCE[counts < min_counts] = np.nan
vmin = np.nanpercentile(avg_LCE, 5)   
vmax = np.nanpercentile(avg_LCE, 95)  
plt.figure(figsize=(8, 7))
mesh = plt.pcolormesh(
    x_bins, y_bins, avg_LCE.T,
    shading='auto',
    cmap='viridis',
    vmin=vmin,
    vmax=vmax
)
plt.colorbar(mesh, label="LCE (%)")
plt.xlabel("X (mm)")
plt.ylabel("Y (mm)")
plt.title(f"LCE Map (bins={n_bins})")
plt.tight_layout()
output_path = "/Users/judyz/Desktop/PET-4x4/build/25.05mm/lce.png"
plt.savefig(output_path, dpi=300)
plt.show()

print("Min LCE:", np.nanmin(avg_LCE))
print("Max LCE:", np.nanmax(avg_LCE))
print("Mean LCE:", np.nanmean(avg_LCE))
# Out:
# Min LCE: 47.98533333333334
# Max LCE: 49.84461538461539
# Mean LCE: 49.1573720648427

# %%
#z = 8.5-9mm
df = pd.read_csv("/Users/judyz/Desktop/PET-4x4/build/40.05mm/40.05mm.csv")
x_min, x_max = -35, 35 
y_min, y_max = -35, 35  
n_bins = 37
x_bins = np.linspace(x_min, x_max, n_bins + 1)
y_bins = np.linspace(y_min, y_max, n_bins + 1)
H, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins], 
    weights=df["LCE (%)"]
)
counts, _, _ = np.histogram2d(
    df["x(mm)"], df["y(mm)"],
    bins=[x_bins, y_bins]
)
avg_LCE = np.full_like(H, np.nan, dtype=float)
valid = counts > 0
avg_LCE[valid] = H[valid] / counts[valid]
min_counts = 1   
avg_LCE[counts < min_counts] = np.nan
vmin = np.nanpercentile(avg_LCE, 5)   
vmax = np.nanpercentile(avg_LCE, 95)  
plt.figure(figsize=(8, 7))
mesh = plt.pcolormesh(
    x_bins, y_bins, avg_LCE.T,
    shading='auto',
    cmap='viridis',
    vmin=vmin,
    vmax=vmax
)
plt.colorbar(mesh, label="LCE (%)")
plt.xlabel("X (mm)")
plt.ylabel("Y (mm)")
plt.title(f"LCE Map (bins={n_bins})")
plt.tight_layout()
output_path = "/Users/judyz/Desktop/PET-4x4/build/40.05mm/lce.png"
plt.savefig(output_path, dpi=300)
plt.show()

print("Min LCE:", np.nanmin(avg_LCE))
print("Max LCE:", np.nanmax(avg_LCE))
print("Mean LCE:", np.nanmean(avg_LCE))
# Out:
# Min LCE: 47.807325000000006
# Max LCE: 49.701027272727266
# Mean LCE: 49.008223924266076
