# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
import copy
import math
import keras
import pandas as pd
import os

from keras.models import Sequential
from keras.layers import Dense, BatchNormalization, Dropout
from keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error

# %%
MLP_distances_all_data = []

# %%
numbers = [3.05, 4.05, 5.05, 6.05, 7.05,8.05, 9.05, 10.05, 11.05, 12.05,13.05, 14.05, 15.05, 16.05, 17.05, 18.05, 19.05, 20.05, 25.05, 40.05]

for q_num, q in enumerate(numbers, start=1):

    file_path = os.path.join('/Users/judyz/Desktop/PET-4x4/build',f'{q}mm',f'{q}mm.csv')
    csvreader = csv.reader(open(file_path))

    original_X = []
    original_y = []

    line_count = 0

    for row in csvreader:
        if line_count >= 1:
            original_X.append([int(i) for i in row[1:17]])
            original_y.append([float(row[17]),float(row[18])])
        line_count += 1

    X = np.array(original_X)
    y = np.array(original_y)

    print("Number of events:", len(X))
    print("X shape:", X.shape)
    print("y shape:", y.shape)
    print("X coordinate range:",np.min(y[:, 0]), "to", np.max(y[:, 0]))
    print("Y coordinate range:",np.min(y[:, 1]), "to", np.max(y[:, 1]))

    # -33 mm to +33 mm in 0.2 mm increments; center-center = index 165
    MLP_distances = np.zeros((331, 331, 2))

    scaler = StandardScaler()

    for k in range(10):
        print(f"Distance {q_num}/{len(numbers)} ({q} mm) | MLP run {k+1}/10")
        X_MLP = scaler.fit_transform(X)
        X_train, X_val, y_train, y_val = train_test_split(X_MLP,y,test_size=0.3)
     
        model = Sequential()
        model.add(Dense(128,input_dim=16,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.2))
        model.add(Dense(128,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.2))
        model.add(Dense(128,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.2))
        model.add(Dense(128,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.2))
        model.add(Dense(2,activation='linear'))

        model.compile(optimizer='adam',loss='mean_squared_error')
            
        history = model.fit(X_train,y_train,epochs=100,batch_size=32,verbose=0)
        yhat = model.predict(X_MLP,verbose=0)

        for i in range(len(X)):
            x_index = 165 + round(y[i][0] * 5)
            y_index = 165 - round(y[i][1] * 5)
            if 0 <= x_index < 331 and 0 <= y_index < 331:
                MLP_distances[x_index,y_index,0] = k/(k+1)*MLP_distances[x_index,y_index,0]+1/(k+1)*(yhat[i][0]-y[i][0])
                MLP_distances[x_index,y_index,1] = k/(k+1)*MLP_distances[x_index,y_index,1]+1/(k+1)*(yhat[i][1]-y[i][1])

    delta_x = MLP_distances[:, :, 0].ravel()
    delta_y = MLP_distances[:, :, 1].ravel()
    delta_x_nonzero = delta_x[delta_x != 0]
    delta_y_nonzero = delta_y[delta_y != 0]

    print("\nMLP Results")
    print("Average MLP Delta X (mm):",np.mean(delta_x_nonzero))
    print("Median MLP Delta X (mm):",np.median(delta_x_nonzero))
    print("Average MLP Delta Y (mm):",np.mean(delta_y_nonzero))
    print("Median MLP Delta Y (mm):",np.median(delta_y_nonzero))

    plt.figure()
    plt.hist(delta_x_nonzero,bins=100,alpha=0.6,label='delta X')
    plt.hist(delta_y_nonzero,bins=100,alpha=0.6,label='delta Y')
    plt.xlabel('Distance Between Original Point and Reconstructed Point (mm)')
    plt.ylabel('Counts')
    plt.legend(loc='upper right')
    plt.title(f'MLP Reconstruction Error — SiPM Distance {q} mm')
    plt.show()

    MLP_distances_all_data.append(MLP_distances)
MLP_distances_all_data_np = np.array(MLP_distances_all_data)

print("\nFinal array shape:",MLP_distances_all_data_np.shape)
# Out:
# Number of events: 20000
# X shape: (20000, 16)
# y shape: (20000, 2)
# X coordinate range: -33.9984 to 33.9977
# Y coordinate range: -33.9965 to 33.9973
# Distance 1/20 (3.05 mm) | MLP run 1/10
# /Users/judyz/Desktop/PET-4x4/venv312/lib/python3.12/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Distance 1/20 (3.05 mm) | MLP run 2/10
# /Users/judyz/Desktop/PET-4x4/venv312/lib/python3.12/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# ...

# %%
np.savetxt('MLP_distances_delta.csv',MLP_distances_all_data_np.reshape(MLP_distances_all_data_np.shape[0],-1))
